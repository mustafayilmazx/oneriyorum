# %%
import numpy as np
import pandas as pd

import networkx as nx
import matplotlib.pyplot as plt
import math as math
import time 
plt.style.use('seaborn')
plt.rcParams['figure.figsize'] = [14,14]

import warnings
warnings.filterwarnings('ignore')

# %%
#amazon = pd.read_csv("amazon_prime_titles.csv")

# %%
#disney = pd.read_csv("disney_plus_titles.csv")

# %%
#netflix = pd.read_csv("netflix_titles.csv")

# %%
#netflix["streaming_service"] = "Netflix"
#amazon["streaming_service"] = "Prime Video"
#disney["streaming_service"] = "Disney+"

# %%
#df = pd.concat([netflix,disney,amazon])

# %%
#df = df[df["type"] == "TV Show"]
#df

# %%
df = pd.read_csv("tv_shows.csv")

# %%
df.drop_duplicates(subset=["title"])
# Out:
#                 show_id     type                    title         director  \
# 0            netflix_s2  TV Show            Blood & Water              NaN
# 1            netflix_s3  TV Show                Ganglands  Julien Leclercq
# 2            netflix_s4  TV Show    Jailbirds New Orleans              NaN
# 3            netflix_s5  TV Show             Kota Factory              NaN
# 4            netflix_s6  TV Show            Midnight Mass    Mike Flanagan
# ...                 ...      ...                      ...              ...
# 4923  prime video_s9652  TV Show               Glass Room              NaN
# 4924  prime video_s9656  TV Show    DaFUNdamentals Series              NaN
# 4925  prime video_s9662  TV Show               Terrahawks              NaN
# 4926  prime video_s9665  TV Show            Planet Patrol              NaN
# 4927  prime video_s9667  TV Show  Maradona: Blessed Dream              NaN
#
#                                                    cast       country  \
# 0     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 1     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 2                                                   NaN           NaN
# 3     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 4     Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
# ...                                                 ...           ...
# 4923  Elizaveta Maiskaya, Vsevolod Boldin, Alexander...           NaN
# 4924         Emile Crawford, Randall Crawford, Jon Ward           NaN
# 4925  DENISE BRYER, WINDSOR DAVIES, JEREMY HITCHEN, ...           NaN
# 4926  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...           NaN
# 4927  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...           NaN
#
#      date_added  release_year rating   duration  ... streaming_service  \
# 0     9/24/2021          2021  TV-MA  2 Seasons  ...           Netflix
# 1     9/24/2021          2021  TV-MA   1 Season  ...           Netflix
# 2     9/24/2021          2021  TV-MA   1 Season  ...           Netflix
# 3     9/24/2021          2021  TV-MA  2 Seasons  ...           Netflix
# 4     9/24/2021          2021  TV-MA   1 Season  ...           Netflix
# ...         ...           ...    ...        ...  ...               ...
# 4923        NaN          2019    16+   1 Season  ...       Prime Video
# 4924        NaN          2021   TV-Y   1 Season  ...       Prime Video
# 4925        NaN          1983    ALL  3 Seasons  ...       Prime Video
# 4926        NaN          2018    13+  4 Seasons  ...       Prime Video
# 4927        NaN          2021  TV-MA   1 Season  ...       Prime Video
#
#         year month   day            directors  \
# 0     2021.0   9.0  24.0                   []
# 1     2021.0   9.0  24.0  ['Julien Leclercq']
# 2     2021.0   9.0  24.0                   []
# 3     2021.0   9.0  24.0                   []
# 4     2021.0   9.0  24.0    ['Mike Flanagan']
# ...      ...   ...   ...                  ...
# 4923     NaN   NaN   NaN                   []
# 4924     NaN   NaN   NaN                   []
# 4925     NaN   NaN   NaN                   []
# 4926     NaN   NaN   NaN                   []
# 4927     NaN   NaN   NaN                   []
#
#                                              categories  \
# 0     ['International TV Shows', 'TV Dramas', 'TV My...
# 1     ['Crime TV Shows', 'International TV Shows', '...
# 2                          ['Docuseries', 'Reality TV']
# 3     ['International TV Shows', 'Romantic TV Shows'...
# 4            ['TV Dramas', 'TV Horror', 'TV Mysteries']
# ...                                                 ...
# 4923                                          ['Drama']
# 4924                              ['Animation', 'Kids']
# 4925                                       ['TV Shows']
# 4926                                       ['TV Shows']
# 4927                                ['Drama', 'Sports']
#
#                                                  actors         countries  \
# 0     ['Ama Qamata', 'Khosi Ngema', 'Gail Mabalane',...  ['South Africa']
# 1     ['Sami Bouajila', 'Tracy Gotoas', 'Samuel Jouy...                []
# 2                                                    []                []
# 3     ['Mayur More', 'Jitendra Kumar', 'Ranjan Raj',...         ['India']
# 4     ['Kate Siegel', 'Zach Gilford', 'Hamish Linkla...                []
# ...                                                 ...               ...
# 4923  ['Elizaveta Maiskaya', 'Vsevolod Boldin', 'Ale...                []
# 4924  ['Emile Crawford', 'Randall Crawford', 'Jon Wa...                []
# 4925  ['DENISE BRYER', 'WINDSOR DAVIES', 'JEREMY HIT...                []
# 4926  ['DICK VOSBURGH', 'RONNIE STEVENS', 'LIBBY MOR...                []
# 4927  ['Esteban Recagno', 'Ezequiel Stremiz', 'Lucia...                []
#
#      cluster                                          image_url
# 0        142  https://image.tmdb.org/t/p/w780/NFHy3z1taQ8nzu...
# 1        142  https://image.tmdb.org/t/p/w780/ui7lPpdLDTivIS...
# 2        142  https://www.themoviedb.org/t/p/w600_and_h900_b...
# 3        142  https://image.tmdb.org/t/p/w780/7Pi6b2gFgwKtxn...
# 4         74  https://image.tmdb.org/t/p/w780/iYoMZYVD775MtB...
# ...      ...                                                ...
# 4923     142                                               None
# 4924     142                                               None
# 4925     142  https://image.tmdb.org/t/p/w780/rCIA8UxTTi2Um2...
# 4926      74                                               None
# 4927     142  https://image.tmdb.org/t/p/w780/qjxEp8azTOezyE...
#
# [4848 rows x 22 columns]

# %%
#df = df.reset_index()

# %%
df
# Out:
#                 show_id     type                    title         director  \
# 0            netflix_s2  TV Show            Blood & Water              NaN
# 1            netflix_s3  TV Show                Ganglands  Julien Leclercq
# 2            netflix_s4  TV Show    Jailbirds New Orleans              NaN
# 3            netflix_s5  TV Show             Kota Factory              NaN
# 4            netflix_s6  TV Show            Midnight Mass    Mike Flanagan
# ...                 ...      ...                      ...              ...
# 4923  prime video_s9652  TV Show               Glass Room              NaN
# 4924  prime video_s9656  TV Show    DaFUNdamentals Series              NaN
# 4925  prime video_s9662  TV Show               Terrahawks              NaN
# 4926  prime video_s9665  TV Show            Planet Patrol              NaN
# 4927  prime video_s9667  TV Show  Maradona: Blessed Dream              NaN
#
#                                                    cast       country  \
# 0     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 1     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 2                                                   NaN           NaN
# 3     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 4     Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
# ...                                                 ...           ...
# 4923  Elizaveta Maiskaya, Vsevolod Boldin, Alexander...           NaN
# 4924         Emile Crawford, Randall Crawford, Jon Ward           NaN
# 4925  DENISE BRYER, WINDSOR DAVIES, JEREMY HITCHEN, ...           NaN
# 4926  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...           NaN
# 4927  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...           NaN
#
#      date_added  release_year rating   duration  ... streaming_service  \
# 0     9/24/2021          2021  TV-MA  2 Seasons  ...           Netflix
# 1     9/24/2021          2021  TV-MA   1 Season  ...           Netflix
# 2     9/24/2021          2021  TV-MA   1 Season  ...           Netflix
# 3     9/24/2021          2021  TV-MA  2 Seasons  ...           Netflix
# 4     9/24/2021          2021  TV-MA   1 Season  ...           Netflix
# ...         ...           ...    ...        ...  ...               ...
# 4923        NaN          2019    16+   1 Season  ...       Prime Video
# 4924        NaN          2021   TV-Y   1 Season  ...       Prime Video
# 4925        NaN          1983    ALL  3 Seasons  ...       Prime Video
# 4926        NaN          2018    13+  4 Seasons  ...       Prime Video
# 4927        NaN          2021  TV-MA   1 Season  ...       Prime Video
#
#         year month   day            directors  \
# 0     2021.0   9.0  24.0                   []
# 1     2021.0   9.0  24.0  ['Julien Leclercq']
# 2     2021.0   9.0  24.0                   []
# 3     2021.0   9.0  24.0                   []
# 4     2021.0   9.0  24.0    ['Mike Flanagan']
# ...      ...   ...   ...                  ...
# 4923     NaN   NaN   NaN                   []
# 4924     NaN   NaN   NaN                   []
# 4925     NaN   NaN   NaN                   []
# 4926     NaN   NaN   NaN                   []
# 4927     NaN   NaN   NaN                   []
#
#                                              categories  \
# 0     ['International TV Shows', 'TV Dramas', 'TV My...
# 1     ['Crime TV Shows', 'International TV Shows', '...
# 2                          ['Docuseries', 'Reality TV']
# 3     ['International TV Shows', 'Romantic TV Shows'...
# 4            ['TV Dramas', 'TV Horror', 'TV Mysteries']
# ...                                                 ...
# 4923                                          ['Drama']
# 4924                              ['Animation', 'Kids']
# 4925                                       ['TV Shows']
# 4926                                       ['TV Shows']
# 4927                                ['Drama', 'Sports']
#
#                                                  actors         countries  \
# 0     ['Ama Qamata', 'Khosi Ngema', 'Gail Mabalane',...  ['South Africa']
# 1     ['Sami Bouajila', 'Tracy Gotoas', 'Samuel Jouy...                []
# 2                                                    []                []
# 3     ['Mayur More', 'Jitendra Kumar', 'Ranjan Raj',...         ['India']
# 4     ['Kate Siegel', 'Zach Gilford', 'Hamish Linkla...                []
# ...                                                 ...               ...
# 4923  ['Elizaveta Maiskaya', 'Vsevolod Boldin', 'Ale...                []
# 4924  ['Emile Crawford', 'Randall Crawford', 'Jon Wa...                []
# 4925  ['DENISE BRYER', 'WINDSOR DAVIES', 'JEREMY HIT...                []
# 4926  ['DICK VOSBURGH', 'RONNIE STEVENS', 'LIBBY MOR...                []
# 4927  ['Esteban Recagno', 'Ezequiel Stremiz', 'Lucia...                []
#
#      cluster                                          image_url
# 0        142  https://image.tmdb.org/t/p/w780/NFHy3z1taQ8nzu...
# 1        142  https://image.tmdb.org/t/p/w780/ui7lPpdLDTivIS...
# 2        142  https://www.themoviedb.org/t/p/w600_and_h900_b...
# 3        142  https://image.tmdb.org/t/p/w780/7Pi6b2gFgwKtxn...
# 4         74  https://image.tmdb.org/t/p/w780/iYoMZYVD775MtB...
# ...      ...                                                ...
# 4923     142                                               None
# 4924     142                                               None
# 4925     142  https://image.tmdb.org/t/p/w780/rCIA8UxTTi2Um2...
# 4926      74                                               None
# 4927     142  https://image.tmdb.org/t/p/w780/qjxEp8azTOezyE...
#
# [4928 rows x 22 columns]

# %%
df["date_added"] = pd.to_datetime(df['date_added'])
df['year'] = df['date_added'].dt.year
df['month'] = df['date_added'].dt.month
df['day'] = df['date_added'].dt.day
# convert columns "director, listed_in, cast and country" in columns that contain a real list
# the strip function is applied on the elements
# if the value is NaN, the new column contains a empty list []
df['directors'] = df['director'].apply(lambda l: [] if pd.isna(l) else [i.strip() for i in l.split(",")])
df['categories'] = df['listed_in'].apply(lambda l: [] if pd.isna(l) else [i.strip() for i in l.split(",")])
df['actors'] = df['cast'].apply(lambda l: [] if pd.isna(l) else [i.strip() for i in l.split(",")])
df['countries'] = df['country'].apply(lambda l: [] if pd.isna(l) else [i.strip() for i in l.split(",")])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.cluster import MiniBatchKMeans

# Build the tfidf matrix with the descriptions
start_time = time.time()
text_content = df['description']
vector = TfidfVectorizer(max_df=0.4,         # drop words that occur in more than X percent of documents
                             min_df=1,      # only use words that appear at least X times
                             stop_words='english', # remove stop words
                             lowercase=True, # Convert everything to lower case 
                             use_idf=True,   # Use idf
                             norm=u'l2',     # Normalization
                             smooth_idf=True # Prevents divide-by-zero errors
                            )
tfidf = vector.fit_transform(text_content)

# Clustering  Kmeans
k = 200
kmeans = MiniBatchKMeans(n_clusters = k)
kmeans.fit(tfidf)
centers = kmeans.cluster_centers_.argsort()[:,::-1]
terms = vector.get_feature_names()

# print the centers of the clusters
# for i in range(0,k):
#     word_list=[]
#     print("cluster%d:"% i)
#     for j in centers[i,:10]:
#         word_list.append(terms[j])
#     print(word_list) 
    
request_transform = vector.transform(df['description'])
# new column cluster based on the description
df['cluster'] = kmeans.predict(request_transform) 

df['cluster'].value_counts().head()
# Out:
# 51     2868
# 52     1845
# 76       15
# 190       4
# 158       3
# Name: cluster, dtype: int64

# %%
def find_similar(tfidf_matrix, index, top_n = 5):
    cosine_similarities = linear_kernel(tfidf_matrix[index:index+1], tfidf_matrix).flatten()
    related_docs_indices = [i for i in cosine_similarities.argsort()[::-1] if i != index]
    return [index for index in related_docs_indices][0:top_n]

# %%
G = nx.Graph(label="MOVIE")
start_time = time.time()
for i, rowi in df.iterrows():
    if (i%1000==0):
        print(" iter {} -- {} seconds --".format(i,time.time() - start_time))
    G.add_node(rowi['title'],key=rowi['index'],label="MOVIE",mtype=rowi['type'],rating=rowi['rating'])
#    G.add_node(rowi['cluster'],label="CLUSTER")
#    G.add_edge(rowi['title'], rowi['cluster'], label="DESCRIPTION")
    for element in rowi['actors']:
        G.add_node(element,label="PERSON")
        G.add_edge(rowi['title'], element, label="ACTED_IN")
    for element in rowi['categories']:
        G.add_node(element,label="CAT")
        G.add_edge(rowi['title'], element, label="CAT_IN")
    for element in rowi['directors']:
        G.add_node(element,label="PERSON")      
        G.add_edge(rowi['title'], element, label="DIRECTED")
    for element in rowi['countries']:
        G.add_node(element,label="COU")
        G.add_edge(rowi['title'], element, label="COU_IN")
    
    indices = find_similar(tfidf, i, top_n = 5)
    snode="Sim("+rowi['title'][:15].strip()+")"        
    G.add_node(snode,label="SIMILAR")
    G.add_edge(rowi['title'], snode, label="SIMILARITY")
    for element in indices:
        G.add_edge(snode, df['title'].loc[element], label="SIMILARITY")
print(" finish -- {} seconds --".format(time.time() - start_time))
# Out:
#  iter 0 -- 0.010033130645751953 seconds --
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Latte\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\Latte\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Latte\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\Latte\Desktop\OneriYorum\recommendation_systems\tvshow_recommendation\tv_show_recommendation.ipynb Cell 15 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Latte/Desktop/OneriYorum/recommendation_systems/tvshow_recommendation/tv_show_recommendation.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a>     if (i%1000==0):
#       <a href='vscode-notebook-cell:/c%3A/Users/Latte/Desktop/OneriYorum/recommendation_systems/tvshow_recommendation/tv_show_recommendation.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a>         print(" iter {} -- {} seconds --".format(i,time.time() - start_time))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Latte/Desktop/OneriYorum/recommendation_systems/tvshow_recommendation/tv_show_recommendation.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a>     G.add_node(rowi['title'],key=rowi['index'],label="MOVIE",mtype=rowi['type'],rating=rowi['rating'])
#       <a href='vscode-notebook-cell:/c%3A/Users/Latte/Desktop/OneriYorum/recommendation_systems/tvshow_recommendation/tv_show_recommendation.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a> #    G.add_node(rowi['cluster'],label="CLUSTER")
#       <a href='vscode-notebook-cell:/c%3A/Users/Latte/Desktop/OneriYorum/recommendation_systems/tvshow_recommendation/tv_show_recommendation.ipynb#X16sZmlsZQ%3D%3D?line=7'>8</a> #    G.add_edge(rowi['title'], rowi['cluster'], label="DESCRIPTION")
#       <a href='vscode-notebook-cell:/c%3A/Users/Latte/Desktop/OneriYorum/recommendation_systems/tvshow_recommendation/tv_show_recommendation.ipynb#X16sZmlsZQ%3D%3D?line=8'>9</a>     for element in rowi['actors']:
#
# File c:\Users\Latte\anaconda3\lib\site-packages\pandas\core\series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File c:\Users\Latte\anaconda3\lib\site-packages\pandas\core\series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File c:\Users\Latte\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'index'

# %%
#index kolonu olustur

# %%
def get_recommendation(root):
    commons_dict = {}
    for e in G.neighbors(root):
        for e2 in G.neighbors(e):
            if e2==root:
                continue
            if G.nodes[e2]['label']=="MOVIE":
                commons = commons_dict.get(e2)
                if commons==None:
                    commons_dict.update({e2 : [e]})
                else:
                    commons.append(e)
                    commons_dict.update({e2 : commons})
    movies=[]
    weight=[]
    for key, values in commons_dict.items():
        w=0.0
        for e in values:
            w=w+1/math.log(G.degree(e))
        movies.append(key) 
        weight.append(w)
    
    result = pd.Series(data=np.array(weight),index=movies)
    result.sort_values(inplace=True,ascending=False)
    final_list = []
    for i in result.index[0:5]:
        final_list.append(i)
    final_list
    return final_list;

# %%
get_recommendation("Stranger Things")
# Out:
# ['Beyond Stranger Things',
#  'Down East Dickering',
#  'Secrets of Sulphur Springs',
#  'Jessie',
#  'Sakho & Mangane']

# %%
# myList = get_recommendation("Stranger Things")
# gocaman_liste = []
# for i in myList:
#     gocaman_liste.append(get_recommendation(i))

# %%
import pickle

# %%
pickle.dump(G, open("graph.pkl", "wb"))
pickle.dump(df, open("df.pkl", "wb"))

# %%
df.to_csv("tv_shows.csv", index=False)

# %%
(df.loc[df["title"] == "Stranger Things"]).to_dict()
# Out:
# {'show_id': {1328: 'netflix_s3686'},
#  'type': {1328: 'TV Show'},
#  'title': {1328: 'Stranger Things'},
#  'director': {1328: nan},
#  'cast': {1328: 'Winona Ryder, David Harbour, Finn Wolfhard, Millie Bobby Brown, Gaten Matarazzo, Caleb McLaughlin, Natalia Dyer, Charlie Heaton, Cara Buono, Noah Schnapp, Matthew Modine, Joe Keery, Dacre Montgomery, Sadie Sink, Paul Reiser, Sean Astin'},
#  'country': {1328: 'United States'},
#  'date_added': {1328: Timestamp('2019-07-04 00:00:00')},
#  'release_year': {1328: 2019},
#  'rating': {1328: 'TV-14'},
#  'duration': {1328: '3 Seasons'},
#  'listed_in': {1328: 'TV Horror, TV Mysteries, TV Sci-Fi & Fantasy'},
#  'description': {1328: 'When a young boy vanishes, a small town uncovers a mystery involving secret experiments, terrifying supernatural forces and one strange little girl.'},
#  'streaming_service': {1328: 'Netflix'},
#  'year': {1328: 2019.0},
#  'month': {1328: 7.0},
#  'day': {1328: 4.0},
#  'directors': {1328: []},
#  'categories': {1328: ['TV Horror', 'TV Mysteries', 'TV Sci-Fi & Fantasy']},
#  'actors': {1328: ['Winona Ryder',
#    'David Harbour',
#    'Finn Wolfhard',
#    'Millie Bobby Brown',
#    'Gaten Matarazzo',
#    'Caleb McLaughlin',
#    'Natalia Dyer',
#    'Charlie Heaton',
#    'Cara Buono',
#    'Noah Schnapp',
#    'Matthew Modine',
#    'Joe Keery',
#    'Dacre Montgomery',
#    'Sadie Sink',
#    'Paul Reiser',
#    'Sean Astin']},
#  'countries': {1328: ['United States']},
#  'cluster': {1328: 51},
#  'image_url': {1328: 'https://image.tmdb.org/t/p/w780/49WJfeN0moxb9IPfGn8AIqMGskD.jpg'}}

# %%
df
# Out:
#                 show_id     type                    title         director  \
# 0            netflix_s2  TV Show            Blood & Water              NaN
# 1            netflix_s3  TV Show                Ganglands  Julien Leclercq
# 2            netflix_s4  TV Show    Jailbirds New Orleans              NaN
# 3            netflix_s5  TV Show             Kota Factory              NaN
# 4            netflix_s6  TV Show            Midnight Mass    Mike Flanagan
# ...                 ...      ...                      ...              ...
# 4923  prime video_s9652  TV Show               Glass Room              NaN
# 4924  prime video_s9656  TV Show    DaFUNdamentals Series              NaN
# 4925  prime video_s9662  TV Show               Terrahawks              NaN
# 4926  prime video_s9665  TV Show            Planet Patrol              NaN
# 4927  prime video_s9667  TV Show  Maradona: Blessed Dream              NaN
#
#                                                    cast       country  \
# 0     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 1     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 2                                                   NaN           NaN
# 3     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 4     Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
# ...                                                 ...           ...
# 4923  Elizaveta Maiskaya, Vsevolod Boldin, Alexander...           NaN
# 4924         Emile Crawford, Randall Crawford, Jon Ward           NaN
# 4925  DENISE BRYER, WINDSOR DAVIES, JEREMY HITCHEN, ...           NaN
# 4926  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...           NaN
# 4927  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...           NaN
#
#      date_added  release_year rating   duration  ... streaming_service  \
# 0    2021-09-24          2021  TV-MA  2 Seasons  ...           Netflix
# 1    2021-09-24          2021  TV-MA   1 Season  ...           Netflix
# 2    2021-09-24          2021  TV-MA   1 Season  ...           Netflix
# 3    2021-09-24          2021  TV-MA  2 Seasons  ...           Netflix
# 4    2021-09-24          2021  TV-MA   1 Season  ...           Netflix
# ...         ...           ...    ...        ...  ...               ...
# 4923        NaT          2019    16+   1 Season  ...       Prime Video
# 4924        NaT          2021   TV-Y   1 Season  ...       Prime Video
# 4925        NaT          1983    ALL  3 Seasons  ...       Prime Video
# 4926        NaT          2018    13+  4 Seasons  ...       Prime Video
# 4927        NaT          2021  TV-MA   1 Season  ...       Prime Video
#
#         year month   day          directors  \
# 0     2021.0   9.0  24.0                 []
# 1     2021.0   9.0  24.0  [Julien Leclercq]
# 2     2021.0   9.0  24.0                 []
# 3     2021.0   9.0  24.0                 []
# 4     2021.0   9.0  24.0    [Mike Flanagan]
# ...      ...   ...   ...                ...
# 4923     NaN   NaN   NaN                 []
# 4924     NaN   NaN   NaN                 []
# 4925     NaN   NaN   NaN                 []
# 4926     NaN   NaN   NaN                 []
# 4927     NaN   NaN   NaN                 []
#
#                                              categories  \
# 0     [International TV Shows, TV Dramas, TV Mysteries]
# 1     [Crime TV Shows, International TV Shows, TV Ac...
# 2                              [Docuseries, Reality TV]
# 3     [International TV Shows, Romantic TV Shows, TV...
# 4                  [TV Dramas, TV Horror, TV Mysteries]
# ...                                                 ...
# 4923                                            [Drama]
# 4924                                  [Animation, Kids]
# 4925                                         [TV Shows]
# 4926                                         [TV Shows]
# 4927                                    [Drama, Sports]
#
#                                                  actors       countries  \
# 0     [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...  [South Africa]
# 1     [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...              []
# 2                                                    []              []
# 3     [Mayur More, Jitendra Kumar, Ranjan Raj, Alam ...         [India]
# 4     [Kate Siegel, Zach Gilford, Hamish Linklater, ...              []
# ...                                                 ...             ...
# 4923  [Elizaveta Maiskaya, Vsevolod Boldin, Alexande...              []
# 4924       [Emile Crawford, Randall Crawford, Jon Ward]              []
# 4925  [DENISE BRYER, WINDSOR DAVIES, JEREMY HITCHEN,...              []
# 4926  [DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, ...              []
# 4927  [Esteban Recagno, Ezequiel Stremiz, Luciano Vi...              []
#
#      cluster                                          image_url
# 0         51  https://image.tmdb.org/t/p/w780/NFHy3z1taQ8nzu...
# 1         51  https://image.tmdb.org/t/p/w780/ui7lPpdLDTivIS...
# 2         51  https://www.themoviedb.org/t/p/w600_and_h900_b...
# 3         51  https://image.tmdb.org/t/p/w780/7Pi6b2gFgwKtxn...
# 4         51  https://image.tmdb.org/t/p/w780/iYoMZYVD775MtB...
# ...      ...                                                ...
# 4923      51                                               None
# 4924      51                                               None
# 4925      51  https://image.tmdb.org/t/p/w780/rCIA8UxTTi2Um2...
# 4926      52                                               None
# 4927      51  https://image.tmdb.org/t/p/w780/qjxEp8azTOezyE...
#
# [4928 rows x 22 columns]
