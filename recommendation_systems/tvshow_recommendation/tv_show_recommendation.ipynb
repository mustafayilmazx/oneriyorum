# %%
import numpy as np
import pandas as pd

import networkx as nx
import matplotlib.pyplot as plt
import math as math
import time 
plt.style.use('seaborn')
plt.rcParams['figure.figsize'] = [14,14]

import warnings
warnings.filterwarnings('ignore')

# %%
amazon = pd.read_csv("amazon_prime_titles.csv")

# %%
disney = pd.read_csv("disney_plus_titles.csv")

# %%
hulu = pd.read_csv("hulu_titles.csv")

# %%
netflix = pd.read_csv("netflix_titles.csv")

# %%
netflix["streaming_service"] = "Netflix"
amazon["streaming_service"] = "Prime Video"
hulu["streaming_service"] = "Hulu"
disney["streaming_service"] = "Disney+"

# %%
df = pd.concat([netflix,disney,amazon])

# %%
df = df[df["type"] == "TV Show"]
df
# Out:
#      show_id     type                    title         director  \
# 1         s2  TV Show            Blood & Water              NaN
# 2         s3  TV Show                Ganglands  Julien Leclercq
# 3         s4  TV Show    Jailbirds New Orleans              NaN
# 4         s5  TV Show             Kota Factory              NaN
# 5         s6  TV Show            Midnight Mass    Mike Flanagan
# ...      ...      ...                      ...              ...
# 9651   s9652  TV Show               Glass Room              NaN
# 9655   s9656  TV Show    DaFUNdamentals Series              NaN
# 9661   s9662  TV Show               Terrahawks              NaN
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
#
#                                                    cast       country  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                   NaN           NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5     Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
# ...                                                 ...           ...
# 9651  Elizaveta Maiskaya, Vsevolod Boldin, Alexander...           NaN
# 9655         Emile Crawford, Randall Crawford, Jon Ward           NaN
# 9661  DENISE BRYER, WINDSOR DAVIES, JEREMY HITCHEN, ...           NaN
# 9664  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...           NaN
# 9666  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...           NaN
#
#               date_added  release_year rating   duration  \
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# 5     September 24, 2021          2021  TV-MA   1 Season
# ...                  ...           ...    ...        ...
# 9651                 NaN          2019    16+   1 Season
# 9655                 NaN          2021   TV-Y   1 Season
# 9661                 NaN          1983    ALL  3 Seasons
# 9664                 NaN          2018    13+  4 Seasons
# 9666                 NaN          2021  TV-MA   1 Season
#
#                                               listed_in  \
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# 5                    TV Dramas, TV Horror, TV Mysteries
# ...                                                 ...
# 9651                                              Drama
# 9655                                    Animation, Kids
# 9661                                           TV Shows
# 9664                                           TV Shows
# 9666                                      Drama, Sports
#
#                                             description streaming_service
# 1     After crossing paths at a party, a Cape Town t...           Netflix
# 2     To protect his family from a powerful drug lor...           Netflix
# 3     Feuds, flirtations and toilet talk go down amo...           Netflix
# 4     In a city of coaching centers known to train I...           Netflix
# 5     The arrival of a charismatic young priest brin...           Netflix
# ...                                                 ...               ...
# 9651  Geography teacher Elena lives with her husband...       Prime Video
# 9655  Learn "daFundamentals" through song and fun ch...       Prime Video
# 9661  This thrilling, action-packed series saw Gerry...       Prime Video
# 9664  This is Earth, 2100AD - and these are the adve...       Prime Video
# 9666  The series tells the story of Diego Maradona, ...       Prime Video
#
# [4928 rows x 13 columns]

# %%
df.drop_duplicates(subset=["title"])
# Out:
#      show_id     type                    title         director  \
# 1         s2  TV Show            Blood & Water              NaN
# 2         s3  TV Show                Ganglands  Julien Leclercq
# 3         s4  TV Show    Jailbirds New Orleans              NaN
# 4         s5  TV Show             Kota Factory              NaN
# 5         s6  TV Show            Midnight Mass    Mike Flanagan
# ...      ...      ...                      ...              ...
# 9651   s9652  TV Show               Glass Room              NaN
# 9655   s9656  TV Show    DaFUNdamentals Series              NaN
# 9661   s9662  TV Show               Terrahawks              NaN
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
#
#                                                    cast       country  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                   NaN           NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5     Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
# ...                                                 ...           ...
# 9651  Elizaveta Maiskaya, Vsevolod Boldin, Alexander...           NaN
# 9655         Emile Crawford, Randall Crawford, Jon Ward           NaN
# 9661  DENISE BRYER, WINDSOR DAVIES, JEREMY HITCHEN, ...           NaN
# 9664  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...           NaN
# 9666  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...           NaN
#
#               date_added  release_year rating   duration  \
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# 5     September 24, 2021          2021  TV-MA   1 Season
# ...                  ...           ...    ...        ...
# 9651                 NaN          2019    16+   1 Season
# 9655                 NaN          2021   TV-Y   1 Season
# 9661                 NaN          1983    ALL  3 Seasons
# 9664                 NaN          2018    13+  4 Seasons
# 9666                 NaN          2021  TV-MA   1 Season
#
#                                               listed_in  \
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# 5                    TV Dramas, TV Horror, TV Mysteries
# ...                                                 ...
# 9651                                              Drama
# 9655                                    Animation, Kids
# 9661                                           TV Shows
# 9664                                           TV Shows
# 9666                                      Drama, Sports
#
#                                             description streaming_service
# 1     After crossing paths at a party, a Cape Town t...           Netflix
# 2     To protect his family from a powerful drug lor...           Netflix
# 3     Feuds, flirtations and toilet talk go down amo...           Netflix
# 4     In a city of coaching centers known to train I...           Netflix
# 5     The arrival of a charismatic young priest brin...           Netflix
# ...                                                 ...               ...
# 9651  Geography teacher Elena lives with her husband...       Prime Video
# 9655  Learn "daFundamentals" through song and fun ch...       Prime Video
# 9661  This thrilling, action-packed series saw Gerry...       Prime Video
# 9664  This is Earth, 2100AD - and these are the adve...       Prime Video
# 9666  The series tells the story of Diego Maradona, ...       Prime Video
#
# [4849 rows x 13 columns]

# %%
df = df.reset_index()

# %%
df
# Out:
#       index show_id     type                    title         director  \
# 0         1      s2  TV Show            Blood & Water              NaN
# 1         2      s3  TV Show                Ganglands  Julien Leclercq
# 2         3      s4  TV Show    Jailbirds New Orleans              NaN
# 3         4      s5  TV Show             Kota Factory              NaN
# 4         5      s6  TV Show            Midnight Mass    Mike Flanagan
# ...     ...     ...      ...                      ...              ...
# 4923   9651   s9652  TV Show               Glass Room              NaN
# 4924   9655   s9656  TV Show    DaFUNdamentals Series              NaN
# 4925   9661   s9662  TV Show               Terrahawks              NaN
# 4926   9664   s9665  TV Show            Planet Patrol              NaN
# 4927   9666   s9667  TV Show  Maradona: Blessed Dream              NaN
#
#                                                    cast       country  \
# 0     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 1     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 2                                                   NaN           NaN
# 3     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 4     Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
# ...                                                 ...           ...
# 4923  Elizaveta Maiskaya, Vsevolod Boldin, Alexander...           NaN
# 4924         Emile Crawford, Randall Crawford, Jon Ward           NaN
# 4925  DENISE BRYER, WINDSOR DAVIES, JEREMY HITCHEN, ...           NaN
# 4926  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...           NaN
# 4927  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...           NaN
#
#               date_added  release_year rating   duration  \
# 0     September 24, 2021          2021  TV-MA  2 Seasons
# 1     September 24, 2021          2021  TV-MA   1 Season
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA  2 Seasons
# 4     September 24, 2021          2021  TV-MA   1 Season
# ...                  ...           ...    ...        ...
# 4923                 NaN          2019    16+   1 Season
# 4924                 NaN          2021   TV-Y   1 Season
# 4925                 NaN          1983    ALL  3 Seasons
# 4926                 NaN          2018    13+  4 Seasons
# 4927                 NaN          2021  TV-MA   1 Season
#
#                                               listed_in  \
# 0       International TV Shows, TV Dramas, TV Mysteries
# 1     Crime TV Shows, International TV Shows, TV Act...
# 2                                Docuseries, Reality TV
# 3     International TV Shows, Romantic TV Shows, TV ...
# 4                    TV Dramas, TV Horror, TV Mysteries
# ...                                                 ...
# 4923                                              Drama
# 4924                                    Animation, Kids
# 4925                                           TV Shows
# 4926                                           TV Shows
# 4927                                      Drama, Sports
#
#                                             description streaming_service
# 0     After crossing paths at a party, a Cape Town t...           Netflix
# 1     To protect his family from a powerful drug lor...           Netflix
# 2     Feuds, flirtations and toilet talk go down amo...           Netflix
# 3     In a city of coaching centers known to train I...           Netflix
# 4     The arrival of a charismatic young priest brin...           Netflix
# ...                                                 ...               ...
# 4923  Geography teacher Elena lives with her husband...       Prime Video
# 4924  Learn "daFundamentals" through song and fun ch...       Prime Video
# 4925  This thrilling, action-packed series saw Gerry...       Prime Video
# 4926  This is Earth, 2100AD - and these are the adve...       Prime Video
# 4927  The series tells the story of Diego Maradona, ...       Prime Video
#
# [4928 rows x 14 columns]

# %%
df["date_added"] = pd.to_datetime(df['date_added'])
df['year'] = df['date_added'].dt.year
df['month'] = df['date_added'].dt.month
df['day'] = df['date_added'].dt.day
# convert columns "director, listed_in, cast and country" in columns that contain a real list
# the strip function is applied on the elements
# if the value is NaN, the new column contains a empty list []
df['directors'] = df['director'].apply(lambda l: [] if pd.isna(l) else [i.strip() for i in l.split(",")])
df['categories'] = df['listed_in'].apply(lambda l: [] if pd.isna(l) else [i.strip() for i in l.split(",")])
df['actors'] = df['cast'].apply(lambda l: [] if pd.isna(l) else [i.strip() for i in l.split(",")])
df['countries'] = df['country'].apply(lambda l: [] if pd.isna(l) else [i.strip() for i in l.split(",")])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.cluster import MiniBatchKMeans

# Build the tfidf matrix with the descriptions
start_time = time.time()
text_content = df['description']
vector = TfidfVectorizer(max_df=0.4,         # drop words that occur in more than X percent of documents
                             min_df=1,      # only use words that appear at least X times
                             stop_words='english', # remove stop words
                             lowercase=True, # Convert everything to lower case 
                             use_idf=True,   # Use idf
                             norm=u'l2',     # Normalization
                             smooth_idf=True # Prevents divide-by-zero errors
                            )
tfidf = vector.fit_transform(text_content)

# Clustering  Kmeans
k = 200
kmeans = MiniBatchKMeans(n_clusters = k)
kmeans.fit(tfidf)
centers = kmeans.cluster_centers_.argsort()[:,::-1]
terms = vector.get_feature_names()

# print the centers of the clusters
# for i in range(0,k):
#     word_list=[]
#     print("cluster%d:"% i)
#     for j in centers[i,:10]:
#         word_list.append(terms[j])
#     print(word_list) 
    
request_transform = vector.transform(df['description'])
# new column cluster based on the description
df['cluster'] = kmeans.predict(request_transform) 

df['cluster'].value_counts().head()
# Out:
# 106    2955
# 49     1762
# 170      15
# 52        2
# 118       2
# Name: cluster, dtype: int64

# %%
def find_similar(tfidf_matrix, index, top_n = 5):
    cosine_similarities = linear_kernel(tfidf_matrix[index:index+1], tfidf_matrix).flatten()
    related_docs_indices = [i for i in cosine_similarities.argsort()[::-1] if i != index]
    return [index for index in related_docs_indices][0:top_n]

# %%
G = nx.Graph(label="MOVIE")
start_time = time.time()
for i, rowi in df.iterrows():
    if (i%1000==0):
        print(" iter {} -- {} seconds --".format(i,time.time() - start_time))
    G.add_node(rowi['title'],key=rowi['index'],label="MOVIE",mtype=rowi['type'],rating=rowi['rating'])
#    G.add_node(rowi['cluster'],label="CLUSTER")
#    G.add_edge(rowi['title'], rowi['cluster'], label="DESCRIPTION")
    for element in rowi['actors']:
        G.add_node(element,label="PERSON")
        G.add_edge(rowi['title'], element, label="ACTED_IN")
    for element in rowi['categories']:
        G.add_node(element,label="CAT")
        G.add_edge(rowi['title'], element, label="CAT_IN")
    for element in rowi['directors']:
        G.add_node(element,label="PERSON")
        G.add_edge(rowi['title'], element, label="DIRECTED")
    for element in rowi['countries']:
        G.add_node(element,label="COU")
        G.add_edge(rowi['title'], element, label="COU_IN")
    
    indices = find_similar(tfidf, i, top_n = 5)
    snode="Sim("+rowi['title'][:15].strip()+")"        
    G.add_node(snode,label="SIMILAR")
    G.add_edge(rowi['title'], snode, label="SIMILARITY")
    for element in indices:
        G.add_edge(snode, df['title'].loc[element], label="SIMILARITY")
print(" finish -- {} seconds --".format(time.time() - start_time))
# Out:
#  iter 0 -- 0.017252445220947266 seconds --
#  iter 1000 -- 5.7444000244140625 seconds --
#  iter 2000 -- 11.438745737075806 seconds --
#  iter 3000 -- 16.506749629974365 seconds --
#  iter 4000 -- 21.6664035320282 seconds --
#  finish -- 26.611268758773804 seconds --

# %%
#index kolonu olustur

# %%
def get_recommendation(root):
    commons_dict = {}
    for e in G.neighbors(root):
        for e2 in G.neighbors(e):
            if e2==root:
                continue
            if G.nodes[e2]['label']=="MOVIE":
                commons = commons_dict.get(e2)
                if commons==None:
                    commons_dict.update({e2 : [e]})
                else:
                    commons.append(e)
                    commons_dict.update({e2 : commons})
    movies=[]
    weight=[]
    for key, values in commons_dict.items():
        w=0.0
        for e in values:
            w=w+1/math.log(G.degree(e))
        movies.append(key) 
        weight.append(w)
    
    result = pd.Series(data=np.array(weight),index=movies)
    result.sort_values(inplace=True,ascending=False)        
    return result;

# %%
result = get_recommendation("Peaky Blinders")
print("peaky blinders icin tavsiyeler")
print(result.head())
# Out:
# peaky blinders icin tavsiyeler
# Jonathan Strange & Mr Norrell    2.914453
# Secret Diary of a Call Girl      2.164043
# The Great Train Robbery          2.099484
# Loaded                           1.936955
# Black Mirror                     1.936955
# dtype: float64
